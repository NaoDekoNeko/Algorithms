# %%
# pip install networkx
# Out:
# ...
#
# ...
#                                               0.0/2.1 MB ? eta -:--:--
#      ----------                               0.5/2.1 MB 17.2 MB/s eta 0:00:01
#      ----------------------                   1.2/2.1 MB 14.7 MB/s eta 0:00:01
#      ------------------------------------     1.9/2.1 MB 14.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 13.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Ejemplo Boruvka

# %%
import networkx as nx
import matplotlib.pyplot as plt

def graficar_grafo(grafo, titulo):
    G = nx.Graph()
    aristas = []
    for i in range(len(grafo)):
        adyacentes = grafo[i]
        for v2, peso in adyacentes:
            aristas.append((i, v2, peso))
    
    for v1, v2, peso in aristas:
        G.add_edge(v1, v2, weight=peso)
    
    pos = nx.spring_layout(G)
    edge_labels = nx.get_edge_attributes(G, 'weight')
    
    nx.draw_networkx(G, pos, with_labels=True, node_color='lightblue', node_size=500, font_size=12, font_weight='bold')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    
    plt.title(titulo)
    plt.axis('off')
    plt.show()

grafo1 = [
    [(1, 2), (2, 4)],
    [(6, 1), (3, 5), (6, 1), (0, 2)],
    [(5, 6), (3, 1), (5, 6), (0, 4)],
    [(5, 2), (4, 10), (5, 2), (2, 1), (1, 5)],
    [(7, 2), (6, 3), (7, 2), (6, 3), (3, 10)],
    [(3, 2), (2, 6), (3, 2), (2, 6)],
    [(4, 3), (1, 1), (4, 3), (1, 1)],
    [(4, 2), (4, 2)]
]

grafo2 = [
    [(2, 4), (1, 2)],
    [(6, 1), (0, 2), (6, 1)],
    [(3, 1), (0, 4), (3, 1)],
    [(5, 2), (2, 1), (5, 2), (2, 1)],
    [(7, 2), (6, 3), (7, 2)],
    [(3, 2), (3, 2)],
    [(4, 3), (1, 1), (1, 1)],
    [(4, 2), (4, 2)]
]

graficar_grafo(grafo1, 'Grafo ')
graficar_grafo(grafo2, 'Boruvka')

# %% [markdown]
# # Ejemplo Kruskal

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Grafo 1
G1 = nx.Graph()
G1.add_edge(0, 1, weight=2)
G1.add_edge(0, 2, weight=4)
G1.add_edge(1, 6, weight=1)
G1.add_edge(1, 3, weight=5)
G1.add_edge(2, 5, weight=6)
G1.add_edge(2, 3, weight=1)
G1.add_edge(3, 5, weight=2)
G1.add_edge(3, 4, weight=10)
G1.add_edge(4, 6, weight=3)
G1.add_edge(4, 7, weight=2)
G1.add_edge(5, 3, weight=2)
G1.add_edge(5, 2, weight=6)
G1.add_edge(6, 1, weight=1)
G1.add_edge(6, 4, weight=3)
G1.add_edge(7, 4, weight=2)

plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G1)
nx.draw(G1, pos, with_labels=True, font_weight='bold', node_color='lightblue', edge_color='gray')
nx.draw_networkx_edge_labels(G1, pos, edge_labels=nx.get_edge_attributes(G1, 'weight'))
plt.title('Grafo')
plt.show()

# Grafo 2
G2 = nx.Graph()
G2.add_edge(0, 2, weight=4)
G2.add_edge(0, 1, weight=2)
G2.add_edge(1, 6, weight=1)
G2.add_edge(2, 3, weight=1)
G2.add_edge(3, 5, weight=2)
G2.add_edge(4, 6, weight=3)
G2.add_edge(4, 7, weight=2)
G2.add_edge(6, 1, weight=1)
G2.add_edge(7, 4, weight=2)

plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G2)
nx.draw(G2, pos, with_labels=True, font_weight='bold', node_color='lightblue', edge_color='gray')
nx.draw_networkx_edge_labels(G2, pos, edge_labels=nx.get_edge_attributes(G2, 'weight'))
plt.title('MST(Kruskal)')
plt.show()

# %% [markdown]
# # Ejemplo Prim

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Grafo 1
G1 = nx.Graph()
G1.add_edge(0, 1, weight=2)
G1.add_edge(0, 2, weight=4)
G1.add_edge(1, 3, weight=5)
G1.add_edge(1, 6, weight=1)
G1.add_edge(2, 3, weight=1)
G1.add_edge(2, 5, weight=6)
G1.add_edge(3, 4, weight=10)
G1.add_edge(3, 5, weight=2)
G1.add_edge(4, 6, weight=3)
G1.add_edge(4, 7, weight=2)
G1.add_edge(5, 3, weight=2)
G1.add_edge(5, 2, weight=6)
G1.add_edge(6, 4, weight=3)
G1.add_edge(6, 1, weight=1)
G1.add_edge(7, 4, weight=2)

plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G1)
nx.draw(G1, pos, with_labels=True, font_weight='bold', node_color='lightblue', edge_color='gray')
nx.draw_networkx_edge_labels(G1, pos, edge_labels=nx.get_edge_attributes(G1, 'weight'))
plt.title('Grafo')
plt.show()

# Grafo 2
G2 = nx.Graph()
G2.add_edge(0, 2, weight=4)
G2.add_edge(0, 1, weight=2)
G2.add_edge(1, 6, weight=1)
G2.add_edge(1, 0, weight=2)
G2.add_edge(2, 3, weight=1)
G2.add_edge(2, 0, weight=4)
G2.add_edge(3, 5, weight=2)
G2.add_edge(3, 2, weight=1)
G2.add_edge(4, 7, weight=2)
G2.add_edge(4, 6, weight=3)
G2.add_edge(5, 3, weight=2)
G2.add_edge(6, 1, weight=1)
G2.add_edge(6, 4, weight=3)
G2.add_edge(7, 4, weight=2)

plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G2)
nx.draw(G2, pos, with_labels=True, font_weight='bold', node_color='lightblue', edge_color='gray')
nx.draw_networkx_edge_labels(G2, pos, edge_labels=nx.get_edge_attributes(G2, 'weight'))
plt.title('MST(Prim)')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el Grafo 1
G1 = nx.Graph()
G1.add_edge(0, 1, weight=2)
G1.add_edge(0, 2, weight=4)
G1.add_edge(1, 3, weight=5)
G1.add_edge(1, 6, weight=1)
G1.add_edge(2, 3, weight=1)
G1.add_edge(2, 5, weight=6)
G1.add_edge(3, 4, weight=10)
G1.add_edge(3, 5, weight=2)
G1.add_edge(4, 6, weight=3)
G1.add_edge(4, 7, weight=2)
G1.add_edge(5, 3, weight=2)
G1.add_edge(5, 2, weight=6)
G1.add_edge(6, 4, weight=3)
G1.add_edge(6, 1, weight=1)
G1.add_edge(7, 4, weight=2)

# Obtener el MST utilizando el algoritmo de Kruskal
T = nx.minimum_spanning_tree(G1)

# Graficar el MST
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G2)
nx.draw(G2, pos, with_labels=True, font_weight='bold', node_color='lightblue', edge_color='gray')
nx.draw_networkx_edge_labels(G2, pos, edge_labels=nx.get_edge_attributes(G2, 'weight'))
plt.title('MST(Prim)')
plt.show()

# %% [markdown]
# # 10 nodos

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Grafo 1
G1 = nx.Graph()
G1.add_edge(0, 9, weight=5)
G1.add_edge(0, 2, weight=2)
G1.add_edge(0, 1, weight=4)
G1.add_edge(1, 4, weight=1)
G1.add_edge(1, 3, weight=3)
G1.add_edge(2, 5, weight=4)
G1.add_edge(2, 4, weight=2)
G1.add_edge(3, 6, weight=2)
G1.add_edge(4, 7, weight=5)
G1.add_edge(4, 6, weight=3)
G1.add_edge(5, 8, weight=2)
G1.add_edge(5, 7, weight=1)
G1.add_edge(6, 9, weight=3)
G1.add_edge(6, 4, weight=3)
G1.add_edge(7, 9, weight=4)
G1.add_edge(7, 5, weight=1)
G1.add_edge(8, 9, weight=2)

# Grafo 2
G2 = nx.Graph()
G2.add_edge(0, 2, weight=2)
G2.add_edge(1, 4, weight=1)
G2.add_edge(2, 4, weight=2)
G2.add_edge(3, 6, weight=2)
G2.add_edge(4, 6, weight=3)
G2.add_edge(4, 2, weight=2)
G2.add_edge(5, 8, weight=2)
G2.add_edge(5, 7, weight=1)
G2.add_edge(6, 4, weight=3)
G2.add_edge(6, 9, weight=3)
G2.add_edge(7, 5, weight=1)
G2.add_edge(8, 5, weight=2)
G2.add_edge(8, 9, weight=2)

# Grafo 3
G3 = nx.Graph()
G3.add_edge(0, 2, weight=2)
G3.add_edge(1, 4, weight=1)
G3.add_edge(2, 4, weight=2)
G3.add_edge(3, 6, weight=2)
G3.add_edge(4, 6, weight=3)
G3.add_edge(4, 2, weight=2)
G3.add_edge(5, 8, weight=2)
G3.add_edge(5, 7, weight=1)
G3.add_edge(6, 4, weight=3)
G3.add_edge(6, 9, weight=3)
G3.add_edge(7, 5, weight=1)
G3.add_edge(8, 5, weight=2)
G3.add_edge(8, 9, weight=2)

# Grafo 4
G4 = nx.Graph()
G4.add_edge(0, 2, weight=2)
G4.add_edge(1, 3, weight=3)
G4.add_edge(1, 4, weight=1)
G4.add_edge(1, 4, weight=1)
G4.add_edge(2, 5, weight=4)
G4.add_edge(2, 4, weight=2)
G4.add_edge(2, 0, weight=2)
G4.add_edge(3, 6, weight=2)
G4.add_edge(3, 1, weight=3)
G4.add_edge(3, 6, weight=2)
G4.add_edge(4, 1, weight=1)
G4.add_edge(4, 2, weight=2)
G4.add_edge(4, 1, weight=1)
G4.add_edge(5, 7, weight=1)
G4.add_edge(5, 8, weight=2)
G4.add_edge(5, 2, weight=4)
G4.add_edge(5, 8, weight=2)
G4.add_edge(5, 7, weight=1)
G4.add_edge(6, 9, weight=3)
G4.add_edge(6, 3, weight=2)
G4.add_edge(6, 3, weight=2)
G4.add_edge(7, 5, weight=1)
G4.add_edge(7, 5, weight=1)
G4.add_edge(8, 5, weight=2)
G4.add_edge(8, 9, weight=2)
G4.add_edge(8, 5, weight=2)
G4.add_edge(9, 6, weight=3)
G4.add_edge(9, 8, weight=2)

# Dibujar los grafos
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
pos1 = nx.spring_layout(G1)
nx.draw(G1, pos1, with_labels=True, node_color='lightblue', edge_color='gray')
labels1 = nx.get_edge_attributes(G1, 'weight')
nx.draw_networkx_edge_labels(G1, pos1, edge_labels=labels1)
plt.title("Grafo")

plt.subplot(2, 2, 2)
pos2 = nx.spring_layout(G2)
nx.draw(G2, pos2, with_labels=True, node_color='lightblue', edge_color='gray')
labels2 = nx.get_edge_attributes(G2, 'weight')
nx.draw_networkx_edge_labels(G2, pos2, edge_labels=labels2)
plt.title("Prim")

plt.subplot(2, 2, 3)
pos3 = nx.spring_layout(G3)
nx.draw(G3, pos3, with_labels=True, node_color='lightblue', edge_color='gray')
labels3 = nx.get_edge_attributes(G3, 'weight')
nx.draw_networkx_edge_labels(G3, pos3, edge_labels=labels3)
plt.title("Kruskal")

plt.subplot(2, 2, 4)
pos4 = nx.spring_layout(G4)
nx.draw(G4, pos4, with_labels=True, node_color='lightblue', edge_color='gray')
labels4 = nx.get_edge_attributes(G4, 'weight')
nx.draw_networkx_edge_labels(G4, pos4, edge_labels=labels4)
plt.title("Boruvka")

plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Grafo 1
G1 = nx.Graph()
G1.add_edge(0, 9, weight=5)
G1.add_edge(0, 2, weight=2)
G1.add_edge(0, 1, weight=4)
G1.add_edge(1, 4, weight=1)
G1.add_edge(1, 3, weight=3)
G1.add_edge(2, 5, weight=4)
G1.add_edge(2, 4, weight=2)
G1.add_edge(3, 6, weight=2)
G1.add_edge(4, 7, weight=5)
G1.add_edge(4, 6, weight=3)
G1.add_edge(5, 8, weight=2)
G1.add_edge(5, 7, weight=1)
G1.add_edge(6, 9, weight=3)
G1.add_edge(6, 4, weight=3)
G1.add_edge(7, 9, weight=4)
G1.add_edge(7, 5, weight=1)
G1.add_edge(8, 9, weight=2)

# Grafo 2
G2 = nx.Graph()
G2.add_edge(0, 2, weight=2)
G2.add_edge(1, 4, weight=1)
G2.add_edge(2, 0, weight=2)
G2.add_edge(3, 6, weight=2)
G2.add_edge(4, 1, weight=1)
G2.add_edge(5, 8, weight=2)
G2.add_edge(5, 7, weight=1)
G2.add_edge(6, 3, weight=2)
G2.add_edge(7, 5, weight=1)
G2.add_edge(8, 9, weight=2)

# Grafo 3
G3 = nx.Graph()
G3.add_edge(0, 2, weight=2)
G3.add_edge(1, 3, weight=3)
G3.add_edge(1, 4, weight=1)
G3.add_edge(2, 0, weight=2)
G3.add_edge(2, 4, weight=2)
G3.add_edge(3, 1, weight=3)
G3.add_edge(3, 6, weight=2)
G3.add_edge(4, 2, weight=2)
G3.add_edge(4, 1, weight=1)
G3.add_edge(5, 8, weight=2)
G3.add_edge(5, 7, weight=1)
G3.add_edge(6, 9, weight=3)
G3.add_edge(6, 3, weight=2)
G3.add_edge(7, 5, weight=1)
G3.add_edge(8, 5, weight=2)
G3.add_edge(8, 9, weight=2)

# Grafo 4
G4 = nx.Graph()
G4.add_edge(0, 2, weight=2)
G4.add_edge(1, 3, weight=3)
G4.add_edge(1, 4, weight=1)
G4.add_edge(1, 4, weight=1)
G4.add_edge(2, 5, weight=4)
G4.add_edge(2, 4, weight=2)
G4.add_edge(2, 0, weight=2)
G4.add_edge(3, 6, weight=2)
G4.add_edge(3, 1, weight=3)
G4.add_edge(3, 6, weight=2)
G4.add_edge(4, 1, weight=1)
G4.add_edge(4, 2, weight=2)
G4.add_edge(4, 1, weight=1)
G4.add_edge(5, 7, weight=1)
G4.add_edge(5, 8, weight=2)
G4.add_edge(5, 2, weight=4)
G4.add_edge(5, 8, weight=2)
G4.add_edge(5, 7, weight=1)
G4.add_edge(6, 9, weight=3)
G4.add_edge(6, 3, weight=2)
G4.add_edge(6, 3, weight=2)
G4.add_edge(7, 5, weight=1)
G4.add_edge(7, 5, weight=1)
G4.add_edge(8, 5, weight=2)
G4.add_edge(8, 9, weight=2)
G4.add_edge(8, 5, weight=2)
G4.add_edge(9, 6, weight=3)
G4.add_edge(9, 8, weight=2)

# Dibujar los grafos
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
pos1 = nx.spring_layout(G1)
nx.draw(G1, pos1, with_labels=True, node_color='lightblue', edge_color='gray')
labels1 = nx.get_edge_attributes(G1, 'weight')
nx.draw_networkx_edge_labels(G1, pos1, edge_labels=labels1)
plt.title("Grafo 1")

plt.subplot(2, 2, 2)
pos2 = nx.spring_layout(G2)
nx.draw(G2, pos2, with_labels=True, node_color='lightblue', edge_color='gray')
labels2 = nx.get_edge_attributes(G2, 'weight')
nx.draw_networkx_edge_labels(G2, pos2, edge_labels=labels2)
plt.title("Grafo 2")

plt.subplot(2, 2, 3)
pos3 = nx.spring_layout(G3)
nx.draw(G3, pos3, with_labels=True, node_color='lightblue', edge_color='gray')
labels3 = nx.get_edge_attributes(G3, 'weight')
nx.draw_networkx_edge_labels(G3, pos3, edge_labels=labels3)
plt.title("Grafo 3")

plt.subplot(2, 2, 4)
pos4 = nx.spring_layout(G4)
nx.draw(G4, pos4, with_labels=True, node_color='lightblue', edge_color='gray')
labels4 = nx.get_edge_attributes(G4, 'weight')
nx.draw_networkx_edge_labels(G4, pos4, edge_labels=labels4)
plt.title("Grafo 4")

plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear un grafo vacío
G = nx.Graph()

# Agregar los vértices al grafo
G.add_nodes_from(range(10))

# Agregar las aristas al grafo con pesos
edges = [
    (0, 1, {'peso': 1}), (1, 0, {'peso': 1}),
    (0, 2, {'peso': 1}), (2, 0, {'peso': 1}),
    (1, 3, {'peso': 1}), (3, 1, {'peso': 1}),
    (0, 4, {'peso': 1}), (4, 0, {'peso': 1}),
    (3, 5, {'peso': 1}), (5, 3, {'peso': 1}),
    (3, 6, {'peso': 1}), (6, 3, {'peso': 1}),
    (6, 7, {'peso': 1}), (7, 6, {'peso': 1}),
    (6, 8, {'peso': 1}), (8, 6, {'peso': 1}),
    (7, 9, {'peso': 1}), (9, 7, {'peso': 1})
]
G.add_edges_from(edges)

# Obtener las etiquetas de las aristas
edge_labels = nx.get_edge_attributes(G, 'peso')

# Graficar el grafo
pos = nx.spring_layout(G)  # Layout para la visualización del grafo
nx.draw(G, pos, with_labels=True, node_size=500, node_color='lightblue', font_size=10, font_weight='bold', edge_color='gray')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Mostrar la imagen del grafo
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el grafo 1
G1 = nx.Graph()

# Definir los vértices adyacentes del grafo 1
adyacencias1 = [
    [4, 2, 1],
    [4, 3, 0],
    [4, 0],
    [4, 6, 5, 1],
    [2, 3, 6, 1, 0],
    [6, 3],
    [8, 7, 5, 4, 3],
    [9, 6],
    [6],
    [7]
]

# Agregar los nodos y las aristas al grafo 1
for i, adyacentes in enumerate(adyacencias1):
    G1.add_edges_from((i, v) for v in adyacentes)

# Crear el grafo 2
G2 = nx.Graph()

# Definir los vértices adyacentes del grafo 2
adyacencias2 = [
    [4, 2, 1, 0, 0],
    [3, 0],
    [0],
    [5, 1],
    [6, 0],
    [3],
    [8, 7, 4],
    [9, 6],
    [6],
    [7]
]

# Agregar los nodos y las aristas al grafo 2
for i, adyacentes in enumerate(adyacencias2):
    G2.add_edges_from((i, v) for v in adyacentes)

# Crear la figura y los ejes
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Dibujar el grafo 1 en el primer eje
pos1 = nx.spring_layout(G1)
nx.draw(G1, pos1, with_labels=True, node_size=300, font_size=8, node_color="lightblue", edge_color="gray", ax=ax[0])
edge_labels1 = nx.get_edge_attributes(G1, 'weight')
nx.draw_networkx_edge_labels(G1, pos1, edge_labels=edge_labels1, ax=ax[0])
ax[0].set_title("Grafo 1")

# Dibujar el grafo 2 en el segundo eje
pos2 = nx.spring_layout(G2)
nx.draw(G2, pos2, with_labels=True, node_size=300, font_size=8, node_color="lightblue", edge_color="gray", ax=ax[1])
edge_labels2 = nx.get_edge_attributes(G2, 'weight')
nx.draw_networkx_edge_labels(G2, pos2, edge_labels=edge_labels2, ax=ax[1])
ax[1].set_title("Grafo 2")

# Ajustar el espaciado entre los subplots
plt.tight_layout()

# Mostrar la imagen con los dos grafos
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el grafo 1
G1 = nx.Graph()

# Definir los vértices adyacentes del grafo 1
adyacencias1 = [
    [4, 2, 1, 4, 2, 1],
    [3, 0, 4, 3, 0],
    [4, 0, 0],
    [6, 5, 4, 1, 6, 5, 1],
    [6, 2, 3, 6, 0, 1, 0],
    [6, 3, 3],
    [8, 7, 4, 3, 8, 7, 5, 4, 3],
    [9, 6, 9, 6],
    [6, 6],
    [7, 7]
]

# Agregar los nodos y las aristas al grafo 1
for i, adyacentes in enumerate(adyacencias1):
    G1.add_edges_from((i, v) for v in adyacentes)

# Crear el grafo 2
G4 = nx.Graph()

# Definir los vértices adyacentes del grafo 2
adyacencias4 = [
    [4, 2, 1],
    [3, 0],
    [0],
    [5, 1, 6],
    [0],
    [3],
    [8, 7, 3],
    [6, 9],
    [6],
    [7]
]

# Agregar los nodos y las aristas al grafo 2
for i, adyacentes in enumerate(adyacencias4):
    G4.add_edges_from((i, v) for v in adyacentes)

# Crear la figura y los ejes
fig, ax = plt.subplots(2, 2, figsize=(10, 5))

# Dibujar el grafo 1 en el primer eje
pos1 = nx.spring_layout(G1)
nx.draw(G1, pos1, with_labels=True, node_size=300, font_size=8, node_color="lightblue", edge_color="gray", ax=ax[0])
edge_labels1 = nx.get_edge_attributes(G1, 'weight')
nx.draw_networkx_edge_labels(G1, pos1, edge_labels=edge_labels1, ax=ax[0])
ax[0].set_title("Grafo 1")

# Dibujar Kruskal en el segundo eje
pos2 = nx.spring_layout(G4)
nx.draw(G2, pos2, with_labels=True, node_size=300, font_size=8, node_color="lightblue", edge_color="gray", ax=ax[1])
edge_labels2 = nx.get_edge_attributes(G4, 'weight')
nx.draw_networkx_edge_labels(G4, pos2, edge_labels=edge_labels2, ax=ax[1])
ax[1].set_title("Kruskal")

# Ajustar el espaciado entre los subplots
plt.tight_layout()

# Mostrar la imagen con los dos grafos
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear los grafos
Grafo = nx.Graph()
Boruvka = nx.Graph()
Prim = nx.Graph()
Kruskal = nx.Graph()

# Definir las adyacencias del Grafo
adyacencias_grafo = [
    [4, 2, 1],
    [3, 0],
    [4, 0],
    [6, 5, 4, 1],
    [6, 2, 3, 0],
    [6, 3],
    [8, 7, 4, 3],
    [9, 6],
    [6],
    [7]
]

# Definir las adyacencias de Boruvka
adyacencias_boruvka = [
    [4, 2, 1],
    [3, 0],
    [0],
    [5, 1, 6],
    [0],
    [3],
    [8, 7, 3],
    [6, 9],
    [6],
    [7]
]

# Definir las adyacencias de Prim
adyacencias_prim = [
    [4, 2, 1],
    [3, 0],
    [0],
    [5, 1, 6],
    [0],
    [3],
    [8, 7, 3],
    [6, 9],
    [6],
    [7]
]

# Definir las adyacencias de Kruskal
adyacencias_kruskal = [
    [4, 2, 1],
    [3, 0],
    [0],
    [5, 1, 6],
    [0],
    [3],
    [8, 7, 3],
    [6, 9],
    [6],
    [7]
]

# Agregar los nodos y las aristas a los grafos
grafos = [Grafo, Boruvka, Prim, Kruskal]
adyacencias = [adyacencias_grafo, adyacencias_boruvka, adyacencias_prim, adyacencias_kruskal]
nombres = ["Grafo", "Boruvka", "Prim", "Kruskal"]

for i, grafo in enumerate(grafos):
    adyacencias_actual = adyacencias[i]
    for j, adyacentes in enumerate(adyacencias_actual):
        grafo.add_edges_from((j, v) for v in adyacentes)

# Crear la figura y los ejes
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

# Dibujar los grafos en los ejes correspondientes
pos = nx.spring_layout(Grafo)
for i, grafo in enumerate(grafos):
    row = i // 2
    col = i % 2
    ax[row, col].set_title(nombres[i])
    nx.draw(grafo, pos, with_labels=True, node_size=300, font_size=8, node_color="lightblue", edge_color="gray", ax=ax[row, col])
    edge_labels = nx.get_edge_attributes(grafo, 'weight')
    nx.draw_networkx_edge_labels(grafo, pos, edge_labels=edge_labels, font_size=6, ax=ax[row, col])

# Ajustar el espaciado entre subplots
plt.subplots_adjust(hspace=0.4)

# Mostrar el gráfico
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el grafo original
grafo_original = nx.Graph()
grafo_original.add_edge(0, 7, weight=8)
grafo_original.add_edge(0, 1, weight=4)
grafo_original.add_edge(1, 7, weight=11)
grafo_original.add_edge(1, 2, weight=8)
grafo_original.add_edge(2, 5, weight=4)
grafo_original.add_edge(2, 8, weight=2)
grafo_original.add_edge(2, 3, weight=7)
grafo_original.add_edge(3, 5, weight=14)
grafo_original.add_edge(3, 4, weight=9)
grafo_original.add_edge(4, 5, weight=10)
grafo_original.add_edge(5, 6, weight=2)
grafo_original.add_edge(6, 8, weight=6)
grafo_original.add_edge(6, 7, weight=1)

# Crear el grafo Kruskal
grafo_kruskal = nx.minimum_spanning_tree(grafo_original)

# Crear el grafo Boruvka
grafo_boruvka = nx.Graph()
grafo_boruvka.add_edge(0, 7, weight=8)
grafo_boruvka.add_edge(1, 2, weight=8)
grafo_boruvka.add_edge(2, 5, weight=4)
grafo_boruvka.add_edge(2, 8, weight=2)
grafo_boruvka.add_edge(3, 5, weight=14)
grafo_boruvka.add_edge(4, 5, weight=10)
grafo_boruvka.add_edge(5, 6, weight=2)
grafo_boruvka.add_edge(6, 7, weight=1)

# Dibujar los grafos
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

axs[0].set_title("Grafo original")
nx.draw_networkx(grafo_original, ax=axs[0], with_labels=True, node_color='lightblue', font_weight='bold')

axs[1].set_title("MST Kruskal")
nx.draw_networkx(grafo_kruskal, ax=axs[1], with_labels=True, node_color='lightgreen', font_weight='bold')

axs[2].set_title("MST Boruvka")
nx.draw_networkx(grafo_boruvka, ax=axs[2], with_labels=True, node_color='lightcoral', font_weight='bold')

plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el grafo original
grafo_original = nx.Graph()
grafo_original.add_edge(0, 7, weight=8)
grafo_original.add_edge(0, 1, weight=4)
grafo_original.add_edge(1, 7, weight=11)
grafo_original.add_edge(1, 2, weight=8)
grafo_original.add_edge(2, 5, weight=4)
grafo_original.add_edge(2, 8, weight=2)
grafo_original.add_edge(2, 3, weight=7)
grafo_original.add_edge(3, 5, weight=14)
grafo_original.add_edge(3, 4, weight=9)
grafo_original.add_edge(4, 5, weight=10)
grafo_original.add_edge(5, 6, weight=2)
grafo_original.add_edge(6, 8, weight=6)
grafo_original.add_edge(6, 7, weight=1)

# Crear el grafo Kruskal
grafo_kruskal = nx.minimum_spanning_tree(grafo_original)

# Crear el grafo Boruvka
grafo_boruvka = nx.Graph()
grafo_boruvka.add_edge(0, 7, weight=8)
grafo_boruvka.add_edge(1, 2, weight=8)
grafo_boruvka.add_edge(2, 5, weight=4)
grafo_boruvka.add_edge(2, 8, weight=2)
grafo_boruvka.add_edge(3, 5, weight=14)
grafo_boruvka.add_edge(4, 5, weight=10)
grafo_boruvka.add_edge(5, 6, weight=2)
grafo_boruvka.add_edge(6, 7, weight=1)

# Dibujar los grafos
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].set_title("Grafo original")
pos = nx.spring_layout(grafo_original)
labels = nx.get_edge_attributes(grafo_original, 'weight')
nx.draw_networkx(grafo_original, pos, ax=axs[0], with_labels=True, node_color='lightblue', font_weight='bold')
nx.draw_networkx_edge_labels(grafo_original, pos, edge_labels=labels, ax=axs[0])

axs[1].set_title("MST Kruskal")
pos = nx.spring_layout(grafo_kruskal)
labels = nx.get_edge_attributes(grafo_kruskal, 'weight')
nx.draw_networkx(grafo_kruskal, pos, ax=axs[1], with_labels=True, node_color='lightgreen', font_weight='bold')
nx.draw_networkx_edge_labels(grafo_kruskal, pos, edge_labels=labels, ax=axs[1])

axs[2].set_title("MST Boruvka")
pos = nx.spring_layout(grafo_boruvka)
labels = nx.get_edge_attributes(grafo_boruvka, 'weight')
nx.draw_networkx(grafo_boruvka, pos, ax=axs[2], with_labels=True, node_color='lightcoral', font_weight='bold')
nx.draw_networkx_edge_labels(grafo_boruvka, pos, edge_labels=labels, ax=axs[2])

plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Grafo original
grafo_original = nx.Graph()
grafo_original.add_edge(0, 7, weight=8)
grafo_original.add_edge(0, 1, weight=4)
grafo_original.add_edge(1, 7, weight=11)
grafo_original.add_edge(1, 2, weight=8)
grafo_original.add_edge(2, 5, weight=4)
grafo_original.add_edge(2, 8, weight=2)
grafo_original.add_edge(2, 3, weight=7)
grafo_original.add_edge(3, 5, weight=14)
grafo_original.add_edge(3, 4, weight=9)
grafo_original.add_edge(4, 5, weight=10)
grafo_original.add_edge(5, 6, weight=2)
grafo_original.add_edge(6, 8, weight=6)
grafo_original.add_edge(6, 7, weight=1)

# Grafo Kruskal
grafo_kruskal = nx.minimum_spanning_tree(grafo_original)

# Grafo Boruvka
grafo_boruvka = nx.Graph()
grafo_boruvka.add_edge(0, 7, weight=8)
grafo_boruvka.add_edge(1, 2, weight=8)
grafo_boruvka.add_edge(2, 5, weight=4)
grafo_boruvka.add_edge(2, 8, weight=2)
grafo_boruvka.add_edge(3, 5, weight=14)
grafo_boruvka.add_edge(4, 5, weight=10)
grafo_boruvka.add_edge(5, 6, weight=2)
grafo_boruvka.add_edge(6, 7, weight=1)

# Grafo Prim
grafo_prim = nx.Graph()
grafo_prim.add_edge(0, 1, weight=4)
grafo_prim.add_edge(1, 0, weight=4)
grafo_prim.add_edge(2, 3, weight=7)
grafo_prim.add_edge(2, 8, weight=2)
grafo_prim.add_edge(3, 4, weight=9)
grafo_prim.add_edge(5, 6, weight=2)
grafo_prim.add_edge(6, 7, weight=1)
grafo_prim.add_edge(8, 2, weight=2)

# Dibujar los grafos
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].set_title("Grafo original")
pos = nx.spring_layout(grafo_original)
labels = nx.get_edge_attributes(grafo_original, 'weight')
nx.draw_networkx(grafo_original, pos, ax=axs[0, 0], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_original, pos, edge_labels=labels, ax=axs[0, 0])

axs[0, 1].set_title("Grafo Kruskal")
pos = nx.spring_layout(grafo_kruskal)
labels = nx.get_edge_attributes(grafo_kruskal, 'weight')
nx.draw_networkx(grafo_kruskal, pos, ax=axs[0, 1], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_kruskal, pos, edge_labels=labels, ax=axs[0, 1])

axs[1, 0].set_title("Grafo Boruvka")
pos = nx.spring_layout(grafo_boruvka)
labels = nx.get_edge_attributes(grafo_boruvka, 'weight')
nx.draw_networkx(grafo_boruvka, pos, ax=axs[1, 0], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_boruvka, pos, edge_labels=labels, ax=axs[1, 0])

axs[1, 1].set_title("Grafo Prim")
pos = nx.spring_layout(grafo_prim)
labels = nx.get_edge_attributes(grafo_prim, 'weight')
nx.draw_networkx(grafo_prim, pos, ax=axs[1, 1], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_prim, pos, edge_labels=labels, ax=axs[1, 1])

plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Grafo original
grafo_original = nx.Graph()
grafo_original.add_edge(0, 7, weight=8)
grafo_original.add_edge(0, 1, weight=4)
grafo_original.add_edge(1, 7, weight=11)
grafo_original.add_edge(1, 2, weight=8)
grafo_original.add_edge(2, 5, weight=4)
grafo_original.add_edge(2, 8, weight=2)
grafo_original.add_edge(2, 3, weight=7)
grafo_original.add_edge(3, 5, weight=14)
grafo_original.add_edge(3, 4, weight=9)
grafo_original.add_edge(4, 5, weight=10)
grafo_original.add_edge(5, 6, weight=2)
grafo_original.add_edge(6, 8, weight=6)
grafo_original.add_edge(6, 7, weight=1)

# Grafo Kruskal
grafo_kruskal = nx.minimum_spanning_tree(grafo_original)

# Grafo Boruvka
grafo_boruvka = nx.Graph()
grafo_boruvka.add_edge(0, 7, weight=8)
grafo_boruvka.add_edge(1, 2, weight=8)
grafo_boruvka.add_edge(2, 5, weight=4)
grafo_boruvka.add_edge(2, 8, weight=2)
grafo_boruvka.add_edge(3, 5, weight=14)
grafo_boruvka.add_edge(4, 5, weight=10)
grafo_boruvka.add_edge(5, 6, weight=2)
grafo_boruvka.add_edge(6, 7, weight=1)

# Grafo Prim
grafo_prim = nx.Graph()
grafo_prim.add_edge(0, 1, weight=4)
grafo_prim.add_edge(1, 0, weight=4)
grafo_prim.add_edge(1, 2, weight=8)
grafo_prim.add_edge(2, 8, weight=2)
grafo_prim.add_edge(2, 5, weight=4)
grafo_prim.add_edge(2, 3, weight=7)
grafo_prim.add_edge(3, 4, weight=9)
grafo_prim.add_edge(5, 6, weight=2)
grafo_prim.add_edge(6, 7, weight=1)

# Dibujar los grafos
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].set_title("Grafo original")
pos = nx.spring_layout(grafo_original)
labels = nx.get_edge_attributes(grafo_original, 'weight')
nx.draw_networkx(grafo_original, pos, ax=axs[0, 0], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_original, pos, edge_labels=labels, ax=axs[0, 0])

axs[0, 1].set_title("Grafo Kruskal")
pos = nx.spring_layout(grafo_kruskal)
labels = nx.get_edge_attributes(grafo_kruskal, 'weight')
nx.draw_networkx(grafo_kruskal, pos, ax=axs[0, 1], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_kruskal, pos, edge_labels=labels, ax=axs[0, 1])

axs[1, 0].set_title("Grafo Boruvka")
pos = nx.spring_layout(grafo_boruvka)
labels = nx.get_edge_attributes(grafo_boruvka, 'weight')
nx.draw_networkx(grafo_boruvka, pos, ax=axs[1, 0], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_boruvka, pos, edge_labels=labels, ax=axs[1, 0])

axs[1, 1].set_title("Grafo Prim")
pos = nx.spring_layout(grafo_prim)
labels = nx.get_edge_attributes(grafo_prim, 'weight')
nx.draw_networkx(grafo_prim, pos, ax=axs[1, 1], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_prim, pos, edge_labels=labels, ax=axs[1, 1])

plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Grafo original
grafo_original = nx.Graph()
grafo_original.add_edge(0, 2, weight=1)
grafo_original.add_edge(0, 1, weight=4)
grafo_original.add_edge(1, 4, weight=3)
grafo_original.add_edge(1, 3, weight=7)
grafo_original.add_edge(1, 2, weight=2)
grafo_original.add_edge(2, 5, weight=6)
grafo_original.add_edge(2, 3, weight=5)
grafo_original.add_edge(3, 5, weight=1)
grafo_original.add_edge(3, 4, weight=2)
grafo_original.add_edge(4, 7, weight=3)
grafo_original.add_edge(4, 6, weight=6)
grafo_original.add_edge(4, 5, weight=4)
grafo_original.add_edge(5, 8, weight=5)
grafo_original.add_edge(5, 7, weight=8)
grafo_original.add_edge(5, 3, weight=1)
grafo_original.add_edge(5, 2, weight=6)
grafo_original.add_edge(6, 9, weight=7)
grafo_original.add_edge(6, 7, weight=1)
grafo_original.add_edge(6, 4, weight=6)
grafo_original.add_edge(7, 8, weight=2)
grafo_original.add_edge(7, 6, weight=1)
grafo_original.add_edge(7, 5, weight=8)
grafo_original.add_edge(7, 4, weight=3)
grafo_original.add_edge(8, 10, weight=3)
grafo_original.add_edge(8, 7, weight=2)
grafo_original.add_edge(8, 5, weight=5)
grafo_original.add_edge(9, 11, weight=4)
grafo_original.add_edge(9, 6, weight=7)
grafo_original.add_edge(10, 8, weight=3)
grafo_original.add_edge(11, 9, weight=4)

# Grafo Prim
grafo_prim = nx.Graph()
grafo_prim.add_edge(0, 2, weight=1)
grafo_prim.add_edge(1, 4, weight=3)
grafo_prim.add_edge(1, 2, weight=2)
grafo_prim.add_edge(3, 5, weight=1)
grafo_prim.add_edge(4, 7, weight=3)
grafo_prim.add_edge(5, 3, weight=1)
grafo_prim.add_edge(6, 9, weight=7)
grafo_prim.add_edge(6, 7, weight=1)
grafo_prim.add_edge(7, 8, weight=2)
grafo_prim.add_edge(8, 10, weight=3)
grafo_prim.add_edge(9, 11, weight=4)

# Grafo Boruvka
grafo_boruvka = nx.Graph()
grafo_boruvka.add_edge(1, 4, weight=3)
grafo_boruvka.add_edge(4, 1, weight=3)
grafo_boruvka.add_edge(2, 3, weight=5)
grafo_boruvka.add_edge(3, 2, weight=5)
grafo_boruvka.add_edge(3, 2, weight=5)
grafo_boruvka.add_edge(2, 3, weight=5)
grafo_boruvka.add_edge(4, 1, weight=3)
grafo_boruvka.add_edge(1, 4, weight=3)
grafo_boruvka.add_edge(5, 8, weight=5)
grafo_boruvka.add_edge(8, 5, weight=5)
grafo_boruvka.add_edge(6, 4, weight=6)
grafo_boruvka.add_edge(4, 6, weight=6)
grafo_boruvka.add_edge(7, 4, weight=3)
grafo_boruvka.add_edge(4, 7, weight=3)
grafo_boruvka.add_edge(8, 5, weight=5)
grafo_boruvka.add_edge(5, 8, weight=5)
grafo_boruvka.add_edge(9, 6, weight=7)
grafo_boruvka.add_edge(6, 9, weight=7)

# Grafo Kruskal
grafo_kruskal = nx.Graph()
grafo_kruskal.add_edge(0, 2, weight=1)
grafo_kruskal.add_edge(1, 4, weight=3)
grafo_kruskal.add_edge(1, 2, weight=2)
grafo_kruskal.add_edge(2, 0, weight=1)
grafo_kruskal.add_edge(3, 4, weight=2)
grafo_kruskal.add_edge(3, 5, weight=1)
grafo_kruskal.add_edge(4, 1, weight=3)
grafo_kruskal.add_edge(4, 7, weight=3)
grafo_kruskal.add_edge(4, 3, weight=2)
grafo_kruskal.add_edge(5, 3, weight=1)
grafo_kruskal.add_edge(6, 9, weight=7)
grafo_kruskal.add_edge(6, 7, weight=1)
grafo_kruskal.add_edge(7, 4, weight=3)
grafo_kruskal.add_edge(7, 8, weight=2)
grafo_kruskal.add_edge(7, 6, weight=1)
grafo_kruskal.add_edge(8, 10, weight=3)
grafo_kruskal.add_edge(8, 7, weight=2)
grafo_kruskal.add_edge(9, 6, weight=7)
grafo_kruskal.add_edge(9, 11, weight=4)
grafo_kruskal.add_edge(11, 9, weight=4)

# Crear la figura y los subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Graficar el grafo original
axs[0, 0].set_title("Grafo Original")
pos = nx.spring_layout(grafo_original)
labels = nx.get_edge_attributes(grafo_original, 'weight')
nx.draw_networkx(grafo_original, pos, ax=axs[0, 0], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_original, pos, edge_labels=labels, ax=axs[0, 0])

# Graficar el grafo Prim
axs[0, 1].set_title("Grafo Prim")
pos = nx.spring_layout(grafo_prim)
labels = nx.get_edge_attributes(grafo_prim, 'weight')
nx.draw_networkx(grafo_prim, pos, ax=axs[0, 1], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_prim, pos, edge_labels=labels, ax=axs[0, 1])

# Graficar el grafo Boruvka
axs[1, 0].set_title("Grafo Boruvka")
pos = nx.spring_layout(grafo_boruvka)
labels = nx.get_edge_attributes(grafo_boruvka, 'weight')
nx.draw_networkx(grafo_boruvka, pos, ax=axs[1, 0], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_boruvka, pos, edge_labels=labels, ax=axs[1, 0])

# Graficar el grafo Kruskal
axs[1, 1].set_title("Grafo Kruskal")
pos = nx.spring_layout(grafo_kruskal)
labels = nx.get_edge_attributes(grafo_kruskal, 'weight')
nx.draw_networkx(grafo_kruskal, pos, ax=axs[1, 1], with_labels=True, node_color='lightblue')
nx.draw_networkx_edge_labels(grafo_kruskal, pos, edge_labels=labels, ax=axs[1, 1])

# Ajustar los espacios entre los subplots
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el grafo
grafo = nx.Graph()
grafo.add_edge(0, 7, weight=31)
grafo.add_edge(0, 2, weight=29)
grafo.add_edge(1, 7, weight=21)
grafo.add_edge(2, 0, weight=29)
grafo.add_edge(3, 4, weight=34)
grafo.add_edge(3, 5, weight=18)
grafo.add_edge(4, 7, weight=46)
grafo.add_edge(4, 3, weight=34)
grafo.add_edge(5, 3, weight=18)
grafo.add_edge(6, 7, weight=25)
grafo.add_edge(7, 4, weight=46)
grafo.add_edge(7, 0, weight=31)
grafo.add_edge(7, 6, weight=25)
grafo.add_edge(7, 1, weight=21)

# Crear la figura y el subplot
fig, ax = plt.subplots(figsize=(8, 6))

# Definir la posición de los nodos utilizando el algoritmo de spring_layout
pos = nx.spring_layout(grafo)

# Dibujar los nodos y las aristas del grafo
nx.draw_networkx_nodes(grafo, pos, ax=ax, node_color='lightblue', node_size=500)
nx.draw_networkx_edges(grafo, pos, ax=ax, width=2)
nx.draw_networkx_labels(grafo, pos, ax=ax, font_size=12, font_color='black')

# Obtener las etiquetas de peso de las aristas
edge_labels = nx.get_edge_attributes(grafo, 'weight')

# Dibujar las etiquetas de peso en las aristas
nx.draw_networkx_edge_labels(grafo, pos, edge_labels=edge_labels, ax=ax, font_size=10)

# Mostrar el gráfico
plt.title("Kruskal")
plt.axis('off')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el grafo
grafo = nx.Graph()
grafo.add_edge(0, 7, weight=31)
grafo.add_edge(0, 2, weight=29)
grafo.add_edge(1, 7, weight=21)
grafo.add_edge(2, 0, weight=29)
grafo.add_edge(3, 5, weight=18)
grafo.add_edge(3, 4, weight=34)
grafo.add_edge(4, 7, weight=46)
grafo.add_edge(4, 3, weight=34)
grafo.add_edge(5, 3, weight=18)
grafo.add_edge(6, 7, weight=25)
grafo.add_edge(7, 0, weight=31)
grafo.add_edge(7, 6, weight=25)
grafo.add_edge(7, 4, weight=46)
grafo.add_edge(7, 1, weight=21)

# Crear la figura y el subplot
fig, ax = plt.subplots(figsize=(8, 6))

# Definir la posición de los nodos utilizando el algoritmo de spring_layout
pos = nx.spring_layout(grafo)

# Dibujar los nodos y las aristas del grafo
nx.draw_networkx_nodes(grafo, pos, ax=ax, node_color='lightblue', node_size=500)
nx.draw_networkx_edges(grafo, pos, ax=ax, width=2)
nx.draw_networkx_labels(grafo, pos, ax=ax, font_size=12, font_color='black')

# Obtener las etiquetas de peso de las aristas
edge_labels = nx.get_edge_attributes(grafo, 'weight')

# Dibujar las etiquetas de peso en las aristas
nx.draw_networkx_edge_labels(grafo, pos, edge_labels=edge_labels, ax=ax, font_size=10)

# Mostrar el gráfico
plt.title("Prim")
plt.axis('off')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el grafo
grafo = nx.Graph()
grafo.add_edge(0, 7, weight=31)
grafo.add_edge(7, 0, weight=31)
grafo.add_edge(1, 0, weight=32)
grafo.add_edge(0, 1, weight=32)
grafo.add_edge(4, 7, weight=46)
grafo.add_edge(7, 4, weight=46)
grafo.add_edge(5, 0, weight=60)
grafo.add_edge(0, 5, weight=60)
grafo.add_edge(6, 4, weight=51)
grafo.add_edge(4, 6, weight=51)
grafo.add_edge(7, 0, weight=31)
grafo.add_edge(0, 7, weight=31)

# Crear la figura y el subplot
fig, ax = plt.subplots(figsize=(8, 6))

# Definir la posición de los nodos utilizando el algoritmo de spring_layout
pos = nx.spring_layout(grafo)

# Dibujar los nodos y las aristas del grafo
nx.draw_networkx_nodes(grafo, pos, ax=ax, node_color='lightblue', node_size=500)
nx.draw_networkx_edges(grafo, pos, ax=ax, width=2)
nx.draw_networkx_labels(grafo, pos, ax=ax, font_size=12, font_color='black')

# Obtener las etiquetas de peso de las aristas
edge_labels = nx.get_edge_attributes(grafo, 'weight')

# Dibujar las etiquetas de peso en las aristas
nx.draw_networkx_edge_labels(grafo, pos, edge_labels=edge_labels, ax=ax, font_size=10)

# Mostrar el gráfico
plt.title("Boruvka")
plt.axis('off')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear el grafo
grafo = nx.Graph()
grafo.add_edge(0, 7, weight=31)
grafo.add_edge(0, 5, weight=60)
grafo.add_edge(0, 2, weight=29)
grafo.add_edge(0, 1, weight=32)
grafo.add_edge(0, 6, weight=53)
grafo.add_edge(1, 7, weight=21)
grafo.add_edge(1, 0, weight=32)
grafo.add_edge(2, 0, weight=29)
grafo.add_edge(3, 5, weight=18)
grafo.add_edge(3, 4, weight=34)
grafo.add_edge(4, 6, weight=51)
grafo.add_edge(4, 5, weight=40)
grafo.add_edge(4, 7, weight=46)
grafo.add_edge(4, 3, weight=34)
grafo.add_edge(5, 0, weight=60)
grafo.add_edge(5, 4, weight=40)
grafo.add_edge(5, 3, weight=18)
grafo.add_edge(6, 7, weight=25)
grafo.add_edge(6, 4, weight=51)
grafo.add_edge(6, 0, weight=53)
grafo.add_edge(7, 1, weight=21)
grafo.add_edge(7, 6, weight=25)
grafo.add_edge(7, 0, weight=31)
grafo.add_edge(7, 4, weight=46)

# Crear la figura y el subplot
fig, ax = plt.subplots(figsize=(8, 6))

# Definir la posición de los nodos utilizando el algoritmo de spring_layout
pos = nx.spring_layout(grafo)

# Dibujar los nodos y las aristas del grafo
nx.draw_networkx_nodes(grafo, pos, ax=ax, node_color='lightblue', node_size=500)
nx.draw_networkx_edges(grafo, pos, ax=ax, width=2)
nx.draw_networkx_labels(grafo, pos, ax=ax, font_size=12, font_color='black')

# Obtener las etiquetas de peso de las aristas
edge_labels = nx.get_edge_attributes(grafo, 'weight')

# Dibujar las etiquetas de peso en las aristas
nx.draw_networkx_edge_labels(grafo, pos, edge_labels=edge_labels, ax=ax, font_size=10)

# Mostrar el gráfico
plt.title("Grafo")
plt.axis('off')
plt.show()

# %% [markdown]
# # Dijkstra ejemplo

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear un grafo dirigido
G = nx.DiGraph()

# Agregar aristas al grafo
G.add_edge(0, 6, weight=53)
G.add_edge(0, 1, weight=32)
G.add_edge(0, 2, weight=29)
G.add_edge(4, 3, weight=34)
G.add_edge(5, 3, weight=18)
G.add_edge(7, 4, weight=46)
G.add_edge(5, 4, weight=40)
G.add_edge(0, 5, weight=60)
G.add_edge(6, 4, weight=51)
G.add_edge(7, 0, weight=31)
G.add_edge(7, 6, weight=25)
G.add_edge(7, 1, weight=21)

# Dibujar el grafo
pos = nx.spring_layout(G, k=7) # Aumentar el valor de k para aumentar la separación entre los nodos
nx.draw(G, pos, with_labels=True)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)

# Mostrar el grafo
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create the original graph
G = nx.DiGraph()
G.add_edge('A', 'F', weight=60)
G.add_edge('A', 'C', weight=29)
G.add_edge('A', 'B', weight=32)
G.add_edge('A', 'G', weight=53)
G.add_edge('E', 'D', weight=34)
G.add_edge('F', 'E', weight=40)
G.add_edge('F', 'D', weight=18)
G.add_edge('G', 'E', weight=51)
G.add_edge('H', 'B', weight=21)
G.add_edge('H', 'G', weight=25)
G.add_edge('H', 'A', weight=31)
G.add_edge('H', 'E', weight=46)

# Draw the original graph
pos = nx.spring_layout(G, k = 5)
nx.draw(G, pos, with_labels=True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.show()

# Create the SPT graph
SPT = nx.DiGraph()
SPT.add_edge('A', 'G', weight=53)
SPT.add_edge('A', 'F', weight=60)
SPT.add_edge('A', 'C', weight=29)
SPT.add_edge('A', 'B', weight=32)
SPT.add_edge('F', 'E', weight=40)
SPT.add_edge('F', 'D', weight=18)

# Draw the SPT graph
pos = nx.spring_layout(SPT, k = 5)
nx.draw(SPT, pos, with_labels=True)
labels = nx.get_edge_attributes(SPT, 'weight')
nx.draw_networkx_edge_labels(SPT, pos, edge_labels=labels)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create the original graph
G = nx.DiGraph()
G.add_edge('A', 'C', weight=1)
G.add_edge('A', 'B', weight=4)
G.add_edge('B', 'E', weight=3)
G.add_edge('B', 'D', weight=7)
G.add_edge('B', 'C', weight=2)
G.add_edge('C', 'F', weight=6)
G.add_edge('C', 'D', weight=5)
G.add_edge('D', 'F', weight=1)
G.add_edge('D', 'E', weight=2)
G.add_edge('E', 'H', weight=3)
G.add_edge('E', 'G', weight=6)
G.add_edge('E', 'F', weight=4)
G.add_edge('F', 'I', weight=5)
G.add_edge('F', 'H', weight=8)
G.add_edge('G', 'J', weight=7)
G.add_edge('G', 'H', weight=1)
G.add_edge('H', 'I', weight=2)
G.add_edge('I', 'K', weight=3)
G.add_edge('J', 'L', weight=4)

# Draw the original graph
pos = nx.spring_layout(G, k = 8)
nx.draw(G, pos, with_labels=True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
plt.figure(figsize=(20, 20))

plt.show()

# Create the SPT graph
SPT = nx.DiGraph()
SPT.add_edge('A', 'C', weight=1)
SPT.add_edge('A', 'B', weight=4)
SPT.add_edge('B', 'E', weight=3)
SPT.add_edge('C', 'F', weight=6)
SPT.add_edge('C', 'D', weight=5)
SPT.add_edge('E','H' ,weight = 3 )
SPT.add_edge('E','G' ,weight = 6 )
SPT.add_edge('F','I' ,weight = 5 )
SPT.add_edge('G','J' ,weight = 7 )
SPT.add_edge('I','K' ,weight = 3 )
SPT.add_edge('J','L' ,weight = 4 )

# Draw the SPT graph
pos = nx.spring_layout(SPT, k = 8)
nx.draw(SPT, pos, with_labels=True)
labels = nx.get_edge_attributes(SPT, 'weight')
nx.draw_networkx_edge_labels(SPT, pos, edge_labels=labels)
plt.figure(figsize=(20, 20))

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create the original graph
G = nx.DiGraph()
G.add_edge('A', 'D', weight=30)
G.add_edge('A', 'E', weight=100)
G.add_edge('A', 'B', weight=10)
G.add_edge('B', 'C', weight=50)
G.add_edge('C', 'E', weight=10)
G.add_edge('D', 'C', weight=20)
G.add_edge('D', 'E', weight=60)

# Draw the original graph
pos = nx.spring_layout(G, k = 5)
nx.draw(G, pos, with_labels=True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.show()

# Create the SPT graph
SPT = nx.DiGraph()
SPT.add_edge('A', 'D', weight=30)
SPT.add_edge('A', 'B', weight=10)
SPT.add_edge('D', 'C', weight=20)
SPT.add_edge('C','E' ,weight = 10 )

# Draw the SPT graph
pos = nx.spring_layout(SPT)
nx.draw(SPT, pos, with_labels=True)
labels = nx.get_edge_attributes(SPT, 'weight')
nx.draw_networkx_edge_labels(SPT, pos, edge_labels=labels)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create the original graph
G = nx.Graph()
G.add_edge('A', 'F', weight=29)
G.add_edge('A', 'D', weight=45)
G.add_edge('A', 'B', weight=41)
G.add_edge('B', 'F', weight=24)
G.add_edge('B', 'E', weight=32)
G.add_edge('B', 'C', weight=51)
G.add_edge('C', 'E', weight=32)
G.add_edge('C', 'D', weight=50)
G.add_edge('D', 'F', weight=38)
G.add_edge('D', 'E', weight=36)
G.add_edge('E', 'F', weight=21)

# Draw the original graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.show()

# Create the SPT graph
SPT = nx.Graph()
SPT.add_edge('A','F' ,weight = 29 )
SPT.add_edge('A','D' ,weight = 45 )
SPT.add_edge('A','B' ,weight = 41 )
SPT.add_edge('E','C' ,weight = 32 )
SPT.add_edge('F','E' ,weight = 21 )

# Draw the SPT graph
pos = nx.spring_layout(SPT)
nx.draw(SPT, pos, with_labels=True)
labels = nx.get_edge_attributes(SPT, 'weight')
nx.draw_networkx_edge_labels(SPT, pos, edge_labels=labels)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_edge(0, 1, weight=-1)
G.add_edge(0, 2, weight=4)
G.add_edge(1, 2, weight=3)
G.add_edge(1, 3, weight=2)
G.add_edge(1, 4, weight=2)
G.add_edge(3, 1, weight=1)
G.add_edge(3, 2, weight=5)
G.add_edge(4, 3, weight=-3)

pos = nx.spring_layout(G, k = 5)
nx.draw(G, pos, with_labels=True)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# First graph
G1 = nx.DiGraph()
G1.add_weighted_edges_from([('A', 'F', 29), ('A', 'B', 41), ('B', 'E', 32), ('B', 'C', 51), ('C', 'D', 50), ('D', 'F', -38), ('D', 'A', 15), ('E', 'C', 32), ('E', 'D', 36), ('F', 'E', 21), ('F', 'B', -29)])

plt.figure(figsize=(18,12))
pos = nx.spring_layout(G1, k = 6)
nx.draw(G1, pos, node_color='red', with_labels=True)
labels = nx.get_edge_attributes(G1, 'weight')
nx.draw_networkx_edge_labels(G1, pos, edge_labels=labels)

plt.show()

# Second graph
G2 = nx.DiGraph()
G2.add_weighted_edges_from([('A', 'F', 29), ('B', 'E', 32), ('B', 'C', 51), ('E', 'D', 36), ('F', 'B', -29)])

plt.figure(figsize=(18,12))
pos = nx.spring_layout(G2, k = 6)
nx.draw(G2, pos, node_color='blue', with_labels=True)
labels = nx.get_edge_attributes(G2, 'weight')
nx.draw_networkx_edge_labels(G2, pos, edge_labels=labels)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

def draw_graph(edges, title):
    G = nx.DiGraph()
    G.add_nodes_from(['A', 'B', 'C', 'D', 'E', 'F'])
    G.add_weighted_edges_from(edges)
    pos = nx.spring_layout(G, k = 6)
    nx.draw(G, pos, with_labels=True)
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
    plt.title(title)
    plt.show()

graphs = [
    {
        'title': 'OG Graph',
        'edges': [('A', 'F', 29), ('A', 'B', 41), ('B', 'E', 32), ('B', 'C', 51), ('C', 'D', 50), ('D', 'F', -38), ('D', 'A', 15), ('E', 'C', 32), ('E', 'D', 36), ('F', 'E', 21), ('F', 'B', -29)]
    },
    {
        'title': 'Graph A',
        'edges': [('A', 'F', 29), ('B', 'E', 32), ('B', 'C', 51), ('E', 'D', 36), ('F', 'B', -29)]
    },
    {
        'title': 'Graph B',
        'edges': [('B', 'E', 32), ('B', 'C', 51), ('D','F','-38'),('D','A','15'),('E','D','36')]
    },
    {
        'title': 'Graph C',
        'edges': [('B','E','32'),('C','D','50'),('D','F','-38'),('D','A','15'),('F','B','-29')]
    },
    {
        'title': 'Graph D',
        'edges': [('B','E','32'),('B','C','51'),('D','F','-38'),('D','A','15'),('F','B','-29')]
    },
    {
        'title': 'Graph E',
        'edges': [('B','C','51'),('D','F','-38'),('D','A','15'),('E','D','36'),('F','B','-29')]
    },
    {
        'title': 'Graph F',
        'edges': [('B','E','32'),('B','C','51'),('D','A','15'),('E','D','36'),('F','B','-29')]
    }
]

for graph in graphs:
    draw_graph(graph['edges'], graph['title'])

# %%
import networkx as nx
import matplotlib.pyplot as plt

def draw_graph(edges, title):
    G = nx.DiGraph()
    G.add_nodes_from(['A', 'B', 'C', 'D', 'E', 'F', 'G'])
    G.add_weighted_edges_from(edges)
    pos = nx.spring_layout(G, k = 7)
    nx.draw(G, pos, with_labels=True)
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
    plt.title(title)
    plt.show()

graphs = [
    {
        'title': 'OG Graph',
        'edges': [('A', 'D', 5), ('A', 'C', 5), ('A', 'B', 6), ('B', 'E', -1), ('C', 'E', 1), ('C', 'B', -2), ('D', 'F', -1), ('D', 'C', -2), ('E', 'G', 3), ('F', 'G', 3)]
    },
    {
        'title': 'Graph A',
        'edges': [('A','D','5'),('B','E','-1'),('C','B','-2'),('D','F','-1'),('D','C','-2'),('E','G','3')]
    },
    {
        'title': 'Graph B',
        'edges': [('B','E','-1'),('E','G','3')]
    },
    {
        'title': 'Graph C',
        'edges': [('B','E','-1'),('C','B','-2'),('E','G','3')]
    },
    {
        'title': 'Graph D',
        'edges': [('B','E','-1'),('C','B','-2'),('D','F','-1'),('D','C','-2'),('E','G','3')]
    },
    {
        'title': 'Graph E',
        'edges': [('E','G','3')]
    },
    {
        'title': 'Graph F',
        'edges': [('F','G','3')]
    },
    {
        'title': 'Graph G',
        'edges': []
    }
]

for graph in graphs:
    draw_graph(graph['edges'], graph['title'])
